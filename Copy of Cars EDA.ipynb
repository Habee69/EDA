# %% [markdown]
# #Car Exploratory Data Analysis
# - Dataset can be found in *https://www.kaggle.com/datasets/CooperUnion/cardataset*

# %% [markdown]
# ##Importing pandas and dataset in the notebook

# %%
import pandas as pd

# %%
data = "data.csv"

# %%
data = pd.read_csv(data)
df = data.copy()

# %%
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %% [markdown]
# ##Data preparation and cleaning

# %%
df.describe()
# Out:
#                Year    Engine HP  Engine Cylinders  Number of Doors  \
# count  11914.000000  11845.00000      11884.000000     11908.000000
# mean    2010.384338    249.38607          5.628829         3.436093
# std        7.579740    109.19187          1.780559         0.881315
# min     1990.000000     55.00000          0.000000         2.000000
# 25%     2007.000000    170.00000          4.000000         2.000000
# 50%     2015.000000    227.00000          6.000000         4.000000
# 75%     2016.000000    300.00000          6.000000         4.000000
# max     2017.000000   1001.00000         16.000000         4.000000
#
#         highway MPG      city mpg    Popularity          MSRP
# count  11914.000000  11914.000000  11914.000000  1.191400e+04
# mean      26.637485     19.733255   1554.911197  4.059474e+04
# std        8.863001      8.987798   1441.855347  6.010910e+04
# min       12.000000      7.000000      2.000000  2.000000e+03
# ...

# %%
df.shape
# Out:
# (11914, 16)

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style',
#        'highway MPG', 'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %%
percentage = (df.isna().sum() / len(df)) *100
percentage
# Out:
# Make                  0.000000
# Model                 0.000000
# Year                  0.000000
# Engine Fuel Type      0.025180
# Engine HP             0.579151
# Engine Cylinders      0.251805
# Transmission Type     0.000000
# Driven_Wheels         0.000000
# Number of Doors       0.050361
# Market Category      31.408427
# Vehicle Size          0.000000
# Vehicle Style         0.000000
# highway MPG           0.000000
# city mpg              0.000000
# Popularity            0.000000
# MSRP                  0.000000
# dtype: float64

# %%
df.Make.unique()
# Out:
# array(['BMW', 'Audi', 'FIAT', 'Mercedes-Benz', 'Chrysler', 'Nissan',
#        'Volvo', 'Mazda', 'Mitsubishi', 'Ferrari', 'Alfa Romeo', 'Toyota',
#        'McLaren', 'Maybach', 'Pontiac', 'Porsche', 'Saab', 'GMC',
#        'Hyundai', 'Plymouth', 'Honda', 'Oldsmobile', 'Suzuki', 'Ford',
#        'Cadillac', 'Kia', 'Bentley', 'Chevrolet', 'Dodge', 'Lamborghini',
#        'Lincoln', 'Subaru', 'Volkswagen', 'Spyker', 'Buick', 'Acura',
#        'Rolls-Royce', 'Maserati', 'Lexus', 'Aston Martin', 'Land Rover',
#        'Lotus', 'Infiniti', 'Scion', 'Genesis', 'HUMMER', 'Tesla',
#        'Bugatti'], dtype=object)

# %%
df['Driven_Wheels'].unique()
# Out:
# array(['rear wheel drive', 'front wheel drive', 'all wheel drive',
#        'four wheel drive'], dtype=object)

# %%
df['Driven_Wheels'].replace('four wheel drive','all wheel drive', inplace=True)

# %%
df['Driven_Wheels'].unique()
# Out:
# array(['rear wheel drive', 'front wheel drive', 'all wheel drive'],
#       dtype=object)

# %% [markdown]
# ## Data Exploratory and Visualization
#  - MSRP
#  - Engine cylinders, Engine HP and Engine fuel type
#
#  - popularity
#  - Model

# %% [markdown]
# ###MSRP

# %%
df.MSRP
# Out:
# 0        46135
# 1        40650
# 2        36350
# 3        29450
# 4        34500
#          ...
# 11909    46120
# 11910    56670
# 11911    50620
# 11912    50920
# 11913    28995
# Name: MSRP, Length: 11914, dtype: int64

# %%
df.MSRP.describe()
# Out:
# count    1.191400e+04
# mean     4.059474e+04
# std      6.010910e+04
# min      2.000000e+03
# 25%      2.100000e+04
# 50%      2.999500e+04
# 75%      4.223125e+04
# max      2.065902e+06
# Name: MSRP, dtype: float64

# %%
df.MSRP.kurt()
# Out:
# 268.92627647631605

# %%
import seaborn as sns

# %%
sns.pairplot(df, hue= 'Popularity',x_vars = 'Make', y_vars = "MSRP")

# %%
df.MSRP.max()
# Out:
# 2065902

# %%
data = df.corr()
sns.heatmap(data)

# %%
sns.scatterplot(x = "Engine HP", y = "MSRP", data = df)

# %% [markdown]
# ###Engine Cylinders

# %%
ec = df['Engine Cylinders']
ec
# Out:
# 0        6
# 1        6
# 2        6
# 3        6
# 4        6
#         ..
# 11909    6
# 11910    6
# 11911    6
# 11912    6
# 11913    6
# Name: Engine Cylinders, Length: 11914, dtype: int64

# %%
ec.fillna(0, inplace = True)
ec.isna().sum()
# Out:
# 0

# %%
ec.unique()
# Out:
# array([ 6.,  4.,  5.,  8., 12.,  0., 10.,  3., 16.])

# %%
df['Engine Cylinders'] = df['Engine Cylinders'].astype(int)
ec
# Out:
# 0        6
# 1        6
# 2        6
# 3        6
# 4        6
#         ..
# 11909    6
# 11910    6
# 11911    6
# 11912    6
# 11913    6
# Name: Engine Cylinders, Length: 11914, dtype: int64

# %%
sns.scatterplot(x="Engine Cylinders", y="Engine HP", data = df )

# %%
bugatti = df[df['Engine Cylinders'] == 16]
bugatti.MSRP.mean()
bugatti
# Out:
#           Make        Model  Year             Engine Fuel Type  Engine HP  \
# 11362  Bugatti  Veyron 16.4  2008  premium unleaded (required)     1001.0
# 11363  Bugatti  Veyron 16.4  2008  premium unleaded (required)     1001.0
# 11364  Bugatti  Veyron 16.4  2009  premium unleaded (required)     1001.0
#
#        Engine Cylinders Transmission Type    Driven_Wheels  Number of Doors  \
# 11362                16  AUTOMATED_MANUAL  all wheel drive              2.0
# 11363                16  AUTOMATED_MANUAL  all wheel drive              2.0
# 11364                16  AUTOMATED_MANUAL  all wheel drive              2.0
#
#                Market Category Vehicle Size Vehicle Style  highway MPG  \
# 11362  Exotic,High-Performance      Compact         Coupe           14
# 11363  Exotic,High-Performance      Compact         Coupe           14
# 11364  Exotic,High-Performance      Compact         Coupe           14
#
#        city mpg  Popularity     MSRP     Drien_Wheels
# ...

# %%
sns.lineplot(x='Engine Cylinders', y='city mpg', data = df).set_title("MPG vs Cylinders")
# Out:
# Text(0.5, 1.0, 'MPG vs Cylinders')

# %%
EFT = df['Engine Fuel Type']
EFT_non_percent = pd.value_counts(EFT)

# %%
EFT_percent = (EFT_non_percent/ len(EFT)) *100
EFT_percent
# Out:
# regular unleaded                                60.198086
# premium unleaded (required)                     16.862515
# premium unleaded (recommended)                  12.783280
# flex-fuel (unleaded/E85)                         7.545745
# diesel                                           1.292597
# electric                                         0.553970
# flex-fuel (premium unleaded required/E85)        0.453248
# flex-fuel (premium unleaded recommended/E85)     0.218231
# flex-fuel (unleaded/natural gas)                 0.050361
# natural gas                                      0.016787
# Name: Engine Fuel Type, dtype: float64

# %%
Check = [print(df[df["Engine Fuel Type"] == 'regular unleaded'].MSRP.mean())
,print(df[df["Engine Fuel Type"] == 'premium unleaded (required)'].MSRP.mean())
,print(df[df["Engine Fuel Type"] == 'premium unleaded (recommended)'].MSRP.mean())
,print(df[df["Engine Fuel Type"] == 'flex-fuel (unleaded/E85)'].MSRP.mean())
,print(df[df["Engine Fuel Type"] == 'diesel'].MSRP.mean())
,print(df[df["Engine Fuel Type"] == 'flex-fuel (premium unleaded required/E85)'].MSRP.mean())
,print(df[df["Engine Fuel Type"] == 'flex-fuel (premium unleaded recommended/E85)'].MSRP.mean())
,print(df[df["Engine Fuel Type"] == 'flex-fuel (unleaded/natural gas)'].MSRP.mean())
,print(df[df["Engine Fuel Type"] == 'natural gas'].MSRP.mean())]
# Out:
# 23013.95552147239
# 101627.09357889497
# 40812.831254103745
# 36258.26028921024
# 40788.0
# 159429.35185185185
# 48641.92307692308
# 39194.166666666664
# 28065.0

# %% [markdown]
# ###Popularity

# %%
df.nlargest(5, columns=['city mpg'])
# Out:
#        Make   Model  Year Engine Fuel Type  Engine HP  Engine Cylinders  \
# 5790    BMW      i3  2015         electric      170.0                 0
# 5791    BMW      i3  2016         electric      170.0                 0
# 5792    BMW      i3  2017         electric      170.0                 0
# 4705  Honda  Fit EV  2013         electric        NaN                 0
# 4706  Honda  Fit EV  2014         electric        NaN                 0
#
#      Transmission Type      Driven_Wheels  Number of Doors   Market Category  \
# 5790      DIRECT_DRIVE   rear wheel drive              4.0  Hatchback,Luxury
# 5791      DIRECT_DRIVE   rear wheel drive              4.0  Hatchback,Luxury
# 5792      DIRECT_DRIVE   rear wheel drive              4.0  Hatchback,Luxury
# 4705      DIRECT_DRIVE  front wheel drive              4.0         Hatchback
# 4706      DIRECT_DRIVE  front wheel drive              4.0         Hatchback
#
# ...

# %% [markdown]
# ##Question and Answers

# %% [markdown]
# ###**which car have 16 cylinders? and how much does it cost?**
#  `Bugatti veyron have 16 cylinders and it costs on average 1,757,223 USD`

# %% [markdown]
# ###**percentage of different fuel types in the list. And which type of fuel used in expensive cars?**
# `flex-fuel (premium unleaded required/E85)`

# %%
EFT_percent
# Out:
# regular unleaded                                60.198086
# premium unleaded (required)                     16.862515
# premium unleaded (recommended)                  12.783280
# flex-fuel (unleaded/E85)                         7.545745
# diesel                                           1.292597
# electric                                         0.553970
# flex-fuel (premium unleaded required/E85)        0.453248
# flex-fuel (premium unleaded recommended/E85)     0.218231
# flex-fuel (unleaded/natural gas)                 0.050361
# natural gas                                      0.016787
# Name: Engine Fuel Type, dtype: float64

# %% [markdown]
# ###**5 most highest mpg car models and their prices**

# %%
df.nlargest(5, columns=['city mpg'])
# Out:
#        Make   Model  Year Engine Fuel Type  Engine HP  Engine Cylinders  \
# 5790    BMW      i3  2015         electric      170.0                 0
# 5791    BMW      i3  2016         electric      170.0                 0
# 5792    BMW      i3  2017         electric      170.0                 0
# 4705  Honda  Fit EV  2013         electric        NaN                 0
# 4706  Honda  Fit EV  2014         electric        NaN                 0
#
#      Transmission Type      Driven_Wheels  Number of Doors   Market Category  \
# 5790      DIRECT_DRIVE   rear wheel drive              4.0  Hatchback,Luxury
# 5791      DIRECT_DRIVE   rear wheel drive              4.0  Hatchback,Luxury
# 5792      DIRECT_DRIVE   rear wheel drive              4.0  Hatchback,Luxury
# 4705      DIRECT_DRIVE  front wheel drive              4.0         Hatchback
# 4706      DIRECT_DRIVE  front wheel drive              4.0         Hatchback
#
# ...

# %% [markdown]
# ###**Is price and number of HP are related?**

# %%
sns.scatterplot(x = "Engine HP", y = "MSRP", data = df)

# %% [markdown]
# ###**Is HP and number of cylinders are related?**

# %%
sns.scatterplot(x="Engine Cylinders", y="Engine HP", data = df )

# %% [markdown]
# ###**Does Increase in Cylinders cause decrease in MPG?**
# `Yes`

# %%
sns.lineplot(x='Engine Cylinders', y='city mpg', data = df).set_title("MPG vs Cylinders")
# Out:
# Text(0.5, 1.0, 'MPG vs Cylinders')
